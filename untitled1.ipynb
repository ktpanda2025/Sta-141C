# %%
import pandas as pd

# %%
kaggle_data = pd.read_csv('Drake_Spotify_Data.csv')

# %%
orginal_full = pd.read_csv('Og_data/Spotify_chart_song_ranks.csv')

# %%
orginal_full["Split_artist_names"]  = orginal_full .artist_names.str.split(',')

# %%
drake_non_kaggle = orginal_full[orginal_full['Split_artist_names'].apply(lambda x: 'Drake' in x)]

# %%
drake_track_non_kaggle = drake_non_kaggle.sort_values("track_name").drop_duplicates(subset='track_name')#102 rows

# %%
drake_track_non_kaggle.columns
# Out:
# Index(['rank', 'uri', 'artist_names', 'track_name', 'source', 'peak_rank',
#        'previous_rank', 'weeks_on_chart', 'streams', 'WeekDate',
#        'Split_artist_names'],
#       dtype='object')

# %%
pd.merge(kaggle_data,drake_non_kaggle,left_on = "track_uri",right_on = "uri",how='inner')
# Out:
#     artist_name               artist_id  ...    WeekDate       Split_artist_names
# 0         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-10-05  [Drake,  Wizkid,  Kyla]
# 1         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-10-12  [Drake,  Wizkid,  Kyla]
# 2         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-07-27  [Drake,  Wizkid,  Kyla]
# 3         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-09-21  [Drake,  Wizkid,  Kyla]
# 4         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-08-31  [Drake,  Wizkid,  Kyla]
# ..          ...                     ...  ...         ...                      ...
# 726       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-24      [Drake,  21 Savage]
# 727       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-10      [Drake,  21 Savage]
# 728       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-17      [Drake,  21 Savage]
# 729       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-10                  [Drake]
# ...

# %%
kaggle_data.columns
# Out:
# Index(['artist_name', 'artist_id', 'album_id', 'album_type',
#        'album_release_date', 'album_release_year',
#        'album_release_date_precision', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'track_id', 'analysis_url',
#        'time_signature', 'disc_number', 'duration_ms', 'explicit',
#        'track_href', 'is_local', 'track_name', 'track_preview_url',
#        'track_number', 'type', 'track_uri', 'external_urls.spotify',
#        'album_name', 'key_name', 'mode_name', 'key_mode'],
#       dtype='object')

# %%
[artist_name', 'artist_id', 'album_release_date',,'danceability', 'energy', 'key','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo', 'track_id']
# Out:
#   Cell In[50], line 1
#     [artist_name', 'artist_id', 'album_release_date',,'danceability', 'energy', 'key','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo', 'track_id']
#                                                                                                                                                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
subset_kaggle = kaggle_data[['artist_name', 'artist_id', 'album_release_date','track_uri','track_name']]
subset_kaggle =subset_kaggle.drop_duplicates(subset='track_uri')
subset_drake_non_kaggle = drake_non_kaggle[['uri', 'artist_names', 'track_name', 'source', 'streams', 'WeekDate']]

# %%
pd.merge(subset_kaggle,drake_non_kaggle,left_on = "track_uri",right_on = "uri",how='inner').drop_duplicates(subset='track_uri')
# Out:
#     artist_name               artist_id  ...    WeekDate       Split_artist_names
# 0         Drake  3TVXtAsR1Inumwj472S9r4  ...  2023-10-05  [Drake,  Wizkid,  Kyla]
# 10        Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-04-07                  [Drake]
# 66        Drake  3TVXtAsR1Inumwj472S9r4  ...  2020-01-02                  [Drake]
# 68        Drake  3TVXtAsR1Inumwj472S9r4  ...  2020-05-07                  [Drake]
# 69        Drake  3TVXtAsR1Inumwj472S9r4  ...  2020-05-07                  [Drake]
# ..          ...                     ...  ...         ...                      ...
# 715       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-24      [Drake,  21 Savage]
# 720       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-24                  [Drake]
# 723       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-24                  [Drake]
# 726       Drake  3TVXtAsR1Inumwj472S9r4  ...  2022-11-24      [Drake,  21 Savage]
# ...

# %%
drake_track_non_kaggle
# Out:
#        rank  ...               Split_artist_names
# 3612     13  ...                          [Drake]
# 29615    16  ...                          [Drake]
# 34767   168  ...                          [Drake]
# 31210    11  ...                          [Drake]
# 32570   171  ...             [Drake,  Chief Keef]
# ...     ...  ...                              ...
# 1828     29  ...                          [Drake]
# 19165   166  ...                          [Drake]
# 27178   179  ...                  [Drake,  Yebba]
# 16065    66  ...                          [Drake]
# 27156   157  ...  [Drake,  Lil Wayne,  Rick Ross]
#
# [102 rows x 11 columns]
